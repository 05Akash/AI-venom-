# %%
import re
import json

# %% [markdown]
# ### Preprocessor function

# %%
def preprocess_cobol_code(cobol_code):
    """Preprocesses COBOL code for conversion to Python.

    Args:
        cobol_code: String containing the COBOL code.

    Returns:
        A string containing the preprocessed COBOL code.
    """

    # Remove comments (lines starting with '*')
    cobol_code = re.sub(r"^\s*\*.*$", "", cobol_code, flags=re.MULTILINE)

    # Remove leading and trailing whitespaces from each line
    cobol_code = "\n".join(line.strip() for line in cobol_code.split("\n"))

    # Replace COBOL keywords with Python equivalents (basic and data type related)
    replacements = {
        "DIVISION.": ":",
        "FD": "FILE",
        "PIC X": "str",
        "PIC 9": "int",
        "PIC 9V9": "float",
        "PROCEDURE": "def",
        "MOVE": "=",
        "ADD": "+=",
        "SUBTRACT": "-=",
        "MULTIPLY": "*=",
        "DISPLAY": "print",
    }
    for old, new in replacements.items():
        cobol_code = cobol_code.replace(old, new)

    # Add necessary indentation for better readability
    cobol_code = add_indentation(cobol_code)

    return cobol_code


def add_indentation(cobol_code):
    """Adds indentation based on COBOL section hierarchy.

    Args:
        cobol_code: String containing the preprocessed COBOL code.

    Returns:
        A string containing the indented COBOL code.
    """

    indentation_level = 0
    indented_code = []
    for line in cobol_code.split("\n"):
        if line.endswith("."):
            indentation_level -= 1
        indented_line = "  " * indentation_level + line
        indented_code.append(indented_line)
        if line.endswith(":"):
            indentation_level += 1
    return "\n".join(indented_code)


def convert_control_flow(cobol_code):
    """Converts basic COBOL control flow statements to Python equivalents.

    Args:
        cobol_code: String containing the preprocessed COBOL code.

    Returns:
        A string containing the COBOL code with converted control flow.
    """

    # Regular expressions for control flow statements
    if_pattern = r"IF\s+(.+?)\s+THEN\s*"
    else_pattern = r"ELSE\s*"
    end_if_pattern = r"END-IF\s*"
    perform_pattern = r"PERFORM\s+(.+?)\s+UNTIL\s+(.+?)\s*"

    # Replace IF-THEN with Python syntax
    cobol_code = re.sub(if_pattern, r"if \1:", cobol_code)

    # Replace ELSE with Python syntax
    cobol_code = re.sub(else_pattern, r"else:", cobol_code)

    # Replace END-IF with indentation adjustment
    cobol_code = re.sub(end_if_pattern, r"", cobol_code)

    # Replace PERFORM UNTIL with Python loop (basic example)
    cobol_code = re.sub(perform_pattern, r"while \2:\n  \1", cobol_code)

    return cobol_code


def call_preprocessor(cobol_code):
    """Calls the preprocessor function and returns the converted code.

    Args:
        cobol_code: String containing the COBOL code.

    Returns:
        A string containing the preprocessed and converted COBOL code.
    """

    # Preprocess the COBOL code
    preprocessed_code = preprocess_cobol_code(cobol_code)

    # Convert control flow statements (can be extended for more complex cases)
    converted_code = convert_control_flow(preprocessed_code)

    return converted_code
# Out:
# IDENTIFICATION :
# PROGRAM-ID. SALARY_CALCULATOR.
# DATA :
# WORKING-STORAGE SECTION.
# 01 EMPLOYEE-NAME str(20).
# 01 HOURS-WORKED int(3) VALUE 0.
# 01 HOURLY-RATE int(5)V99 VALUE 0.
# 01 SALARY int(6)V99 VALUE 0.
# def :
# ACCEPT EMPLOYEE-NAME FROM CONSOLE.
# ACCEPT HOURS-WORKED FROM CONSOLE.
# ACCEPT HOURLY-RATE FROM CONSOLE.
# COMPUTE SALARY = HOURS-WORKED * HOURLY-RATE.
# print 'Employee: ', EMPLOYEE-NAME.
# print 'Salary: ', SALARY.

# %%
with open("data.json", "r") as json_file:
    data = json.load(json_file)

# %%
for entry in data:
    cobol_code = entry["cobol_code"]
    preprocessed_code = preprocess_cobol_code(cobol_code)
    converted_code = call_preprocessor(preprocessed_code)

    # Now you can use converted_code for further processing or saving to a file
    # For example, if you want to save each converted code to a separate file
    program_name = entry["documentation"]["program_name"]
    with open(f"{program_name}_converted.py", "w") as python_file:
        python_file.write(converted_code)

# %%
for entry in data:
    program_name = entry["documentation"]["program_name"]
    description = entry["documentation"]["description"]
    purpose = entry["documentation"]["purpose"]
    usage = entry["documentation"].get("usage", "Usage information not available")

    print(f"Program Name: {program_name}")
    print(f"Description: {description}")
    print(f"Purpose: {purpose}")
    print(f"Usage: {usage}")
    print()
# Out:
# Program Name: SALARY_CALCULATOR
# Description: This program calculates the salary of an employee based on the hours worked and hourly rate.
# Purpose: Demonstrate basic salary calculation using user input in COBOL.
# Usage: Run the program and input employee data when prompted. The program will calculate and display the salary.
#
# Program Name: STUDENT_GRADE_CALCULATOR
# Description: This program calculates the grade of a student based on marks obtained.
# Purpose: Demonstrate grade calculation using conditional statements in COBOL.
# Usage: Run the program and input the student's name and marks obtained. The program will calculate and display the grade.
#
# Program Name: EMPLOYEE_INFO
# Description: This program retrieves employee information from a file based on the employee ID.
# Purpose: Demonstrate file handling and record retrieval in COBOL.
# Usage: Run the program and input an employee ID to retrieve the corresponding employee information.
#
# Program Name: INVENTORY_MANAGER
# Description: This program manages inventory by updating the quantity of a product.
# Purpose: Demonstrate file handling, record retrieval, and quantity update in COBOL.
# Usage: Run the program and input a product ID and quantity to update the inventory quantity.
#
# Program Name: STUDENT_RECORD_MANAGER
# Description: This program calculates the average marks of students stored in a file.
# Purpose: Demonstrate file handling, record processing, and average calculation in COBOL.
# Usage: Run the program to calculate and display the average marks of students stored in the file.
#
# Program Name: ATM_TRANSACTION
# Description: This program simulates an ATM transaction system.
# Purpose: Demonstrate basic ATM transaction functionalities in COBOL.
# Usage: Run the program to simulate an ATM transaction based on user input.
#
# Program Name: EMPLOYEE_BONUS_CALCULATOR
# Description: This program calculates the bonus for an employee based on their salary.
# Purpose: Demonstrate bonus calculation based on salary ranges in COBOL.
# Usage: Run the program and input employee ID and salary when prompted. The program will calculate and display the bonus.
#
# Program Name: BANK_TRANSACTION
# Description: This program simulates bank transactions such as withdrawals and deposits.
# Purpose: Demonstrate basic banking operations in COBOL.
# Usage: Run the program to simulate bank transactions based on user input.
#
# Program Name: STUDENT_ATTENDANCE
# Description: This program retrieves student attendance data from a file based on the student's roll number.
# Purpose: Demonstrate file handling and record retrieval in COBOL.
# Usage: Run the program and input a student's roll number to retrieve their attendance days.
#
# Program Name: CUSTOMER_INFO
# Description: This program retrieves customer information from a file based on the customer ID.
# Purpose: Demonstrate file handling and record retrieval in COBOL.
# Usage: Run the program and input a customer ID to retrieve the corresponding customer information.
#
# Program Name: EMPLOYEE_SALARY_REPORT
# Description: This program calculates the total salary of employees.
# Purpose: Demonstrate computation and accumulation of salaries in COBOL.
# Usage: Run the program to calculate the total salary of employees in the file.
#
# Program Name: INVOICE_GENERATOR
# Description: This program generates an invoice based on product sales.
# Purpose: Demonstrate computation of total amount for product sales in COBOL.
# Usage: Run the program to generate an invoice for a product based on the input product code and quantity sold.
#
# Program Name: STUDENT_MARKS_REPORT
# Description: This program generates a report of total and average marks for students.
# Purpose: Demonstrate computation of total and average marks in COBOL.
# Usage: Run the program to generate a report of total and average marks for students in the file.
#
# Program Name: CUSTOMER_BILLING
# Description: This program calculates the billing amount for customers based on units used.
# Purpose: Demonstrate conditional billing calculation in COBOL.
# Usage: Run the program to calculate the billing amount for customers.
#
# Program Name: STUDENT_ADMISSION
# Description: This program selects students for admission based on their marks.
# Purpose: Demonstrate conditional selection of students in COBOL.
# Usage: Run the program to select students for admission based on marks.
#
# Program Name: STOCK_PRICE_CALCULATOR
# Description: This program calculates the total value of stock based on stock prices.
# Purpose: Demonstrate computation of total stock value in COBOL.
# Usage: Run the program to calculate the total value of stock based on stock prices.
#
# Program Name: PRODUCT_SALES_REPORT
# Description: This program generates a report of total sales based on product orders.
# Purpose: Demonstrate computation of total sales in COBOL.
# Usage: Run the program to generate a report of total sales based on product orders.
#
# Program Name: EMPLOYEE_PAYROLL
# Description: This program calculates the total payroll based on employee hours worked and hourly wage.
# Purpose: Demonstrate payroll computation in COBOL.
# Usage: Run the program to calculate the total payroll based on employee hours worked and hourly wage.
#
# Program Name: STUDENT_MARKSHEET_GENERATOR
# Description: This program generates a marksheet for students based on their marks and calculates their grades.
# Purpose: Demonstrate grade calculation based on average marks in COBOL.
# Usage: Run the program to generate a marksheet and calculate grades for students.
#
# Program Name: ORDER_PROCESSING
# Description: This program calculates the total value of orders processed.
# Purpose: Demonstrate computation of total orders value in COBOL.
# Usage: Run the program to calculate the total value of orders processed.
#
# Program Name: CUSTOMER_INFO_MANAGER
# Description: This program manages customer information and displays details based on customer ID.
# Purpose: Demonstrate customer info management in COBOL.
# Usage: Run the program to manage and display customer information.
#
# Program Name: STUDENT_INFO_MANAGER
# Description: This program manages student information and displays details based on roll number.
# Purpose: Demonstrate student info management in COBOL.
# Usage: Run the program to manage and display student information.
#
# Program Name: PRODUCT_INFO_MANAGER
# Description: This program retrieves product information from a file based on the product ID provided by the user.
# Purpose: Demonstrate file input/output and record retrieval in COBOL.
# Usage: Usage information not available
#
# Program Name: STUDENT_MARKS_MANAGER
# Description: This program retrieves student marks from a file based on the roll number provided by the user and calculates the total marks.
# Purpose: Demonstrate file input/output, record retrieval, and computation in COBOL.
# Usage: Usage information not available
#
# Program Name: PRODUCT_MANAGER
# Description: This program retrieves product information from a file based on the product ID provided by the user.
# Purpose: Demonstrate file input/output and record retrieval in COBOL.
# Usage: Usage information not available
#
# Program Name: STUDENT_INFO
# Description: This program retrieves student information from a file based on the roll number provided by the user.
# Purpose: Demonstrate file input/output and record retrieval in COBOL.
# Usage: Usage information not available
#
# Program Name: MARKSHEET_GENERATOR
# Description: This program calculates and displays the total marks, average marks, and grade for each student from a file until the end-of-file marker '99999' is reached.
# Purpose: Demonstrate file input/output, record processing, computation, and conditional logic in COBOL.
# Usage: Usage information not available
#
# Program Name: BILLING_SYSTEM
# Description: This program calculates the bill amount for each customer based on the units of electricity used. Customers are prompted to enter their ID, and the bill amount is computed accordingly until '99999' is entered.
# Purpose: Demonstrate file input/output, record processing, computation, and conditional logic in COBOL.
# Usage: Usage information not available
#
# Program Name: ATTENDANCE_SYSTEM
# Description: This program retrieves student attendance information from a file based on the roll number provided by the user.
# Purpose: Demonstrate file input/output and record retrieval in COBOL.
# Usage: Usage information not available
#
# Program Name: SALES_REPORT
# Description: This program calculates and displays the total sales from a sales file until the end-of-file marker '99999999' is reached.
# Purpose: Demonstrate file input/output, record processing, computation, and conditional logic in COBOL.
# Usage: Usage information not available
#
# Program Name: STUDENT_REPORT
# Description: This program calculates and displays the total and average marks for each student from a student file until the end-of-file marker '99999' is reached.
# Purpose: Demonstrate file input/output, record processing, computation, and conditional logic in COBOL.
# Usage: Usage information not available
#
# Program Name: LIBRARY_SYSTEM
# Description: This program retrieves book information from a file based on the book ID provided by the user.
# Purpose: Demonstrate file input/output and record retrieval in COBOL.
# Usage: Usage information not available
#
# Program Name: SALARY_CALCULATOR
# Description: This program calculates the salary of an employee based on the number of hours worked and the hourly rate provided by the user.
# Purpose: Demonstrate computation and console input/output in COBOL.
# Usage: Usage information not available
#
# Program Name: STUDENT_GRADE_CALCULATOR
# Description: This program calculates the grade of a student based on the marks obtained.
# Purpose: Demonstrate conditional logic and console input/output in COBOL.
# Usage: Usage information not available
#
# Program Name: EMPLOYEE_INFO
# Description: This program retrieves employee information from a file based on the employee ID provided by the user.
# Purpose: Demonstrate file input/output and record retrieval in COBOL.
# Usage: Usage information not available
#
# Program Name: INVENTORY_MANAGER
# Description: This program updates the quantity of a product in the inventory based on the product ID provided by the user.
# Purpose: Demonstrate file input/output and record processing in COBOL.
# Usage: Usage information not available
#
# Program Name: STUDENT_RECORD_MANAGER
# Description: This program calculates the average marks of students from a file until the end-of-file marker '99999' is reached.
# Purpose: Demonstrate file input/output, record processing, and computation in COBOL.
# Usage: Usage information not available
#
# Program Name: ATM_TRANSACTION
# Description: This program simulates an ATM transaction by allowing users to withdraw or deposit money from their account.
# Purpose: Demonstrate console input/output and conditional logic in COBOL.
# Usage: Usage information not available
#
# Program Name: EMPLOYEE_BONUS_CALCULATOR
# Description: This program calculates the bonus for an employee based on their salary.
# Purpose: Demonstrate computation and conditional logic in COBOL.
# Usage: Usage information not available
#
# Program Name: BANK_TRANSACTION
# Description: This program simulates a bank transaction by allowing users to withdraw or deposit money from their account.
# Purpose: Demonstrate console input/output and conditional logic in COBOL.
# Usage: Usage information not available
#
# Program Name: STUDENT_ATTENDANCE
# Description: This program retrieves and displays the attendance record of a student.
# Purpose: Demonstrate file input/output and record retrieval in COBOL.
# Usage: Usage information not available
#
# Program Name: CUSTOMER_INFO
# Description: This program retrieves and displays information about a customer based on the customer ID.
# Purpose: Demonstrate file input/output and record retrieval in COBOL.
# Usage: Usage information not available
#
# Program Name: EMPLOYEE_SALARY_REPORT
# Description: This program calculates the total salary of all employees.
# Purpose: Demonstrate file input/output and computation in COBOL.
# Usage: Usage information not available
#
# Program Name: INVOICE_GENERATOR
# Description: This program generates an invoice based on the product code and quantity sold.
# Purpose: Demonstrate file input/output and computation in COBOL.
# Usage: Usage information not available
#
# Program Name: STUDENT_MARKS_REPORT
# Description: This program generates a report of students' marks including total and average marks.
# Purpose: Demonstrate file input/output and computation in COBOL.
# Usage: Usage information not available
#
# Program Name: CUSTOMER_BILLING
# Description: This program calculates the billing amount for customers based on the units they have used.
# Purpose: Demonstrate file input/output and computation in COBOL.
# Usage: Usage information not available
#
# Program Name: STUDENT_ADMISSION
# Description: This program selects students for admission based on their marks.
# Purpose: Demonstrate file input/output and conditional processing in COBOL.
# Usage: Usage information not available
#
# Program Name: STOCK_PRICE_CALCULATOR
# Description: This program calculates the total value of the stock based on its price.
# Purpose: Demonstrate file input/output and computation in COBOL.
# Usage: Usage information not available
#
# Program Name: PRODUCT_SALES_REPORT
# Description: This program generates a report of total sales for products based on sales records.
# Purpose: Demonstrate file input/output and computation in COBOL.
# Usage: Usage information not available
#
# Program Name: EMPLOYEE_PAYROLL
# Description: This program calculates the total payroll based on hours worked and hourly wage for employees.
# Purpose: Demonstrate file input/output and computation in COBOL.
# Usage: Usage information not available
#
# Program Name: STUDENT_MARKSHEET_GENERATOR
# Description: This program generates student marksheets including total marks, average marks, and grades based on individual subject marks.
# Purpose: Demonstrate file input/output, computation, and conditional processing in COBOL.
# Usage: Usage information not available
#
# Program Name: ORDER_PROCESSING
# Description: This program calculates the total order value based on order records.
# Purpose: Demonstrate file input/output and computation in COBOL.
# Usage: Usage information not available
#
# Program Name: CUSTOMER_INFO_MANAGER
# Description: This program manages customer information such as customer ID, name, and city.
# Purpose: Demonstrate file input/output and conditional processing in COBOL.
# Usage: Usage information not available
#
# Program Name: STUDENT_INFO_MANAGER
# Description: This program manages student information such as roll number, name, and age.
# Purpose: Demonstrate file input/output and conditional processing in COBOL.
# Usage: Usage information not available
#
# Program Name: PRODUCT_INFO_MANAGER
# Description: This program manages product information such as product ID, name, and category.
# Purpose: Demonstrate file input/output and conditional processing in COBOL.
# Usage: Usage information not available
#
# Program Name: STUDENT_MARKS_MANAGER
# Description: This program manages student marks such as roll number and marks in three subjects.
# Purpose: Demonstrate file input/output and conditional processing in COBOL.
# Usage: Usage information not available
#
# Program Name: PRODUCT_MANAGER
# Description: This program manages product information such as product ID, name, and category.
# Purpose: Demonstrate file input/output and conditional processing in COBOL.
# Usage: Usage information not available
#
# Program Name: STUDENT_INFO
# Description: This program manages student information such as roll number, name, and age.
# Purpose: Demonstrate file input/output and conditional processing in COBOL.
# Usage: Usage information not available
#
# Program Name: MARKSHEET_GENERATOR
# Description: This program generates a marksheet for students based on their marks.
# Purpose: Demonstrate file input/output and conditional processing in COBOL.
# Usage: Usage information not available
#
# Program Name: BILLING_SYSTEM
# Description: This program calculates the bill amount for customers based on the units they used.
# Purpose: Demonstrate file input/output and conditional processing in COBOL.
# Usage: Usage information not available
#
# Program Name: ATTENDANCE_SYSTEM
# Description: This program displays the attendance days of a student based on their roll number.
# Purpose: Demonstrate file input/output and basic data processing in COBOL.
# Usage: Usage information not available
#
# Program Name: SALES_REPORT
# Description: This program calculates and displays the total sales from the sales records.
# Purpose: Demonstrate file input/output and data processing in COBOL.
# Usage: Usage information not available
#
# Program Name: STUDENT_REPORT
# Description: This program displays the total and average marks of students from the student records.
# Purpose: Demonstrate file input/output and data processing in COBOL.
# Usage: Usage information not available
#
# Program Name: LIBRARY_SYSTEM
# Description: This program retrieves and displays information about a book from a library database.
# Purpose: Demonstrate file input/output and data processing in COBOL.
# Usage: Usage information not available
#
# Program Name: EMPLOYEE_DATABASE
# Description: This program retrieves and displays information about employees from an employee database.
# Purpose: Demonstrate file input/output and data processing in COBOL.
# Usage: Usage information not available
#
# Program Name: STUDENT_RECORDS
# Description: This program reads student records from a file and calculates their average marks and whether they pass or fail based on the marks obtained.
# Purpose: Demonstrate file input/output and data processing in COBOL.
# Usage: Usage information not available
